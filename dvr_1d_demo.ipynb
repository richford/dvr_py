# %% [markdown]
# ## Demo Area

# %% [markdown]
# Use matplotlib inline so that plots show up in the notebook.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Next import the `dvr_1d` module. We import dvr_1d using a series of ipython notebook magic commands so that we can make changes to the module file and test those changes in this notebook without having to restart the notebook kernel.

# %%
# autoreload the lattice module so that we can make changes to it 
# without restarting the ipython notebook server
# %load_ext autoreload
# %autoreload 1
# %aimport dvr_1d
# %aimport dvr_2d
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# First, we'll test the sinc function DVR on a simple harmonic oscillator potential.

# %%
d = dvr_1d.SincDVR(43, 20)
d.sho_test(precision=12)
# Out:
# Testing 1-D DVR with an SHO potential
# The first 5 energies are:
# [ 0.5  1.5  2.5  3.5  4.5]

# %% [markdown]
# Let's try the same potential but with a Hermite basis. We see that since the Hermite polynomials are the exact solutions to the SHO problem, we can use `npts == num_eigs`. The eigenvectors will look horrible but the eigenvalues will be very accurate.

# %%
d = dvr_1d.HermiteDVR(npts=5)
d.sho_test(k=1., precision=11)
# Out:
# Testing 1-D DVR with an SHO potential
# The first 5 energies are:
# [ 0.5  1.5  2.5  3.5  4.5]

# %%
d = dvr_1d.SincDVR(npts=1000, L=20)
d.square_well_test(precision=6)
d.inf_square_well_test(precision=6)
# Out:
# Testing 1-D DVR with a finite square-well potential
# The first 5 energies are:
# [ 0.043362  0.173341  0.389605  0.691548  1.078202]
# Compare to these energies:
# [ 0.043362  0.173349  0.389619  0.691573  1.078236]
# from: http://pilotscholars.up.edu/phy_facpubs/8
#
# Testing 1-D DVR with an infinite square-well potential
# The first 5 energies are:
# [ 0.049198  0.196793  0.442785  0.787173  1.229958]
# Compare to the exact energies:
# [ 0.049348  0.197392  0.444132  0.789568  1.233701]

# %%
d = dvr_1d.HermiteDVR(npts=268)
d.square_well_test(precision=6)
d.inf_square_well_test(precision=6)
# Out:
# Testing 1-D DVR with a finite square-well potential
# The first 5 energies are:
# [ 0.042387  0.169452  0.380892  0.676162  1.054384]
# Compare to these energies:
# [ 0.043362  0.173349  0.389619  0.691573  1.078236]
# from: http://pilotscholars.up.edu/phy_facpubs/8
#
# Testing 1-D DVR with an infinite square-well potential
# The first 5 energies are:
# [ 0.047259  0.189037  0.425334  0.75615   1.181485]
# Compare to the exact energies:
# [ 0.049348  0.197392  0.444132  0.789568  1.233701]

# %%
d = dvr_1d.SineDVR(npts=100, xmin=-20, xmax=20)
d.sho_test(precision=13)
d.square_well_test(precision=6)
d.inf_square_well_test(precision=6)
# Out:
# Testing 1-D DVR with an SHO potential
# The first 5 energies are:
# [ 0.5  1.5  2.5  3.5  4.5]
# Testing 1-D DVR with a finite square-well potential
# The first 5 energies are:
# [ 0.042798  0.171122  0.384753  0.683286  1.066064]
# Compare to these energies:
# [ 0.043362  0.173349  0.389619  0.691573  1.078236]
# from: http://pilotscholars.up.edu/phy_facpubs/8
#
# Testing 1-D DVR with an infinite square-well potential
# The first 5 energies are:
# [ 0.046479  0.185916  0.418322  0.74368   1.162045]
# Compare to the exact energies:
# [ 0.049348  0.197392  0.444132  0.789568  1.233701]

# %% [markdown]
# ## Testing Area

# %%
# %matplotlib osx
d1d = dvr_1d.SincDVR(npts = 30, L=10)
d2d = dvr_2d.DVR(dvr1d=d1d)
E, U = d2d.sho_test(num_eigs=5, uscale=3., doshow=True)
# Out:
# Testing 2-D DVR with an SHO potential
# The first 5 energies are:
# [ 1.          2.          2.          3.          3.00000003]

# %%
vF = dvr_2d.VFactory()
V = vF.sho()
Vplt = V(d2d.xy)
xy = d2d.xy.reshape((d2d.dvr1d.npts, d2d.dvr1d.npts, 2))
Vplt = Vplt.reshape((d2d.dvr1d.npts, d2d.dvr1d.npts))

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xyplt[:,:,0], xyplt[:,:,1], Vplt)

# %%
# %matplotlib osx
d1d = dvr_1d.HermiteDVR(npts = 100)
d2d = dvr_2d.DVR(dvr1d=d1d)
E, U = d2d.sho_test(num_eigs=5, doshow=True)
# Out:
# Testing 2-D DVR with an SHO potential
# The first 5 energies are:
# [ 10.00000017  19.99999656  19.99999656  29.99999294  30.00006005]

# %%
print U
# Out:
# [[ -4.31065263e-06   2.82058360e-05   9.05663612e-06  -1.14186794e-04
#    -8.16034563e-05]
#  [ -5.71645036e-05   3.40660836e-04   5.51421628e-05  -1.11313543e-03
#    -8.86622195e-04]
#  [ -2.87025059e-04   1.56648699e-03  -3.30703096e-06  -3.91930350e-03
#    -3.90186984e-03]
#  [ -7.64214093e-04   3.81511570e-03  -7.00981560e-04  -6.44274254e-03
#    -9.67625407e-03]
#  [ -1.21886562e-03   5.53827070e-03  -2.18156663e-03  -4.33365627e-03
#    -1.52757922e-02]
#  [ -1.21886562e-03   4.99794039e-03  -3.23299663e-03   1.35485456e-03
#    -1.60251158e-02]
#  [ -7.64214093e-04   2.79096204e-03  -2.69388453e-03   4.33938295e-03
#    -1.10965379e-02]
#  [ -2.87025059e-04   9.14636919e-04  -1.27174357e-03   2.94326942e-03
#    -4.80584758e-03]
#  [ -5.71645036e-05   1.53484924e-04  -3.09083874e-04   8.57422536e-04
#    -1.14619547e-03]
#  [ -4.31065263e-06   9.05663612e-06  -2.82058360e-05   8.74129110e-05
#    -1.08159334e-04]
#  [ -5.71645036e-05   3.09083874e-04   1.53484924e-04  -1.12781317e-03
#    -7.70227413e-04]
#  [ -7.58070934e-04   3.65613068e-03   1.17395014e-03  -1.08621983e-02
#    -7.45965540e-03]
#  [ -3.80630184e-03   1.64481689e-02   2.17894710e-03  -3.76811702e-02
#    -2.94667694e-02]
#  [ -1.01344096e-02   3.90766707e-02  -3.37758144e-03  -6.04383497e-02
#    -6.72863055e-02]
#  [ -1.61636424e-02   5.50763826e-02  -1.94909940e-02  -3.76582581e-02
#    -1.02590340e-01]
#  [ -1.61636424e-02   4.79109446e-02  -3.34342362e-02   1.79447021e-02
#    -1.09914683e-01]
#  [ -1.01344096e-02   2.54951458e-02  -2.98059019e-02   4.49526941e-02
#    -8.11690226e-02]
#  [ -3.80630184e-03   7.80384321e-03  -1.46420662e-02   2.93977861e-02
#    -3.83027970e-02]
